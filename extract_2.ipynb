# %%
import pickle
from bs4 import BeautifulSoup
from library.utilities import *
import pandas as pd

# %%
df = get_pickle('data/links.pickle'); df.head(3)
# Out:
#   network   host        date  \
# 0     fox  kelly  2015-12-17
# 1     fox  kelly  2015-01-22
# 2     fox  kelly  2015-10-16
#
#                                                 link
# 0  http://www.foxnews.com/transcript/2015/12/17/k...
# 1  http://www.foxnews.com/transcript/2015/01/22/d...
# 2  http://www.foxnews.com/transcript/2015/10/16/f...

# %%
df[(df['network'] == 'cnn')]
# Out:
#     network     host        date  \
# 1       cnn   cooper  2015-09-10
# 9       cnn   cooper  2016-06-15
# 16      cnn   cooper  2016-04-06
# 17      cnn   cooper  2015-03-12
# 18      cnn   cooper  2016-01-06
# 20      cnn   cooper  2015-07-30
# 22      cnn   cooper  2016-04-21
# 24      cnn   cooper  2015-12-04
# 33      cnn   cooper  2015-12-03
# 55      cnn   cooper  2015-12-18
# 60      cnn   cooper  2015-12-03
# 63      cnn   cooper  2016-05-25
# 66      cnn   cooper  2015-05-21
# 67      cnn   cooper  2015-02-25
# 70      cnn   cooper  2015-01-08
# 74      cnn   cooper  2015-04-21
# 77      cnn   cooper  2016-05-25
# 80      cnn   cooper  2015-11-19
# 86      cnn   cooper  2015-12-02
# 87      cnn   cooper  2015-11-16
# 96      cnn   cooper  2015-10-19
# 101     cnn   cooper  2015-05-28
# 109     cnn   cooper  2015-02-02
# 110     cnn   cooper  2015-08-06
# 111     cnn   cooper  2016-07-06
# 113     cnn   cooper  2015-02-06
# 125     cnn   cooper  2016-04-15
# ...
