# %%
import pickle
from bs4 import BeautifulSoup
from library.utilities import *
import pandas as pd

# %%
df = get_pickle('data/links.pickle')
df_fox = df[(df['network'] == 'fox')]
df_cnn = df[(df['network'] == 'cnn')]
df_msnbc = df[(df['network'] == 'msnbc')]

# %%
mkdir('data/transcripts')

# %%
df.head(3)
# Out:
#   network   host        date  \
# 0     fox  kelly  2015-12-17
# 1     fox  kelly  2015-01-22
# 2     fox  kelly  2015-10-16
#
#                                                 link text
# 0  http://www.foxnews.com/transcript/2015/12/17/k...
# 1  http://www.foxnews.com/transcript/2015/01/22/d...
# 2  http://www.foxnews.com/transcript/2015/10/16/f...

# %%
df_cnn.head(3)
# Out:
#    network    host        date  \
# 1      cnn  cooper  2015-09-10
# 9      cnn  cooper  2016-06-15
# 16     cnn  cooper  2016-04-06
#
#                                                  link text
# 1   http://transcripts.cnn.com/TRANSCRIPTS/1509/10...
# 9   http://transcripts.cnn.com/TRANSCRIPTS/1606/15...
# 16  http://transcripts.cnn.com/TRANSCRIPTS/1604/06...

# %%
df_cnn_test = df_cnn.iloc[:5]; df_cnn_test
# Out:
#    network    host        date  \
# 1      cnn  cooper  2015-09-10
# 9      cnn  cooper  2016-06-15
# 16     cnn  cooper  2016-04-06
# 17     cnn  cooper  2015-03-12
# 18     cnn  cooper  2016-01-06
#
#                                                  link text
# 1   http://transcripts.cnn.com/TRANSCRIPTS/1509/10...
# 9   http://transcripts.cnn.com/TRANSCRIPTS/1606/15...
# 16  http://transcripts.cnn.com/TRANSCRIPTS/1604/06...
# 17  http://transcripts.cnn.com/TRANSCRIPTS/1503/12...
# 18  http://transcripts.cnn.com/TRANSCRIPTS/1601/06...

# %%
len(cnn_transcripts)
# Out:
# 1788

# %%
# Out:
# [['(COMMERCIAL BREAK)',
#   '',
#   "[21:00:35] ANDERSON COOPER, AC360 HOST:  Hey good evening.  Thanks for joining us 9:00 P.M., in New York, where we have breaking news.  New polling that will not be welcome news for Hillary Clinton, it is 6:00 P.M., the Reagan Library in Simi Valley, Southern California, site of next week's CNN Republican Presidential Debate.  Now just six days away, the breaking news on that, we can now say that these are the 11 candidates who qualify for the main debate.  Rand Paul, Huckabee, Marco Rubio, Ted Cruz, Dr. Ben Carson, Donald Trump, Jeb Bush, Scott Walker, Carly Fiorina, John Kasick, and Chris Christie.",
#   '',
# ...

# %%
stuff = cnn_transcripts[:40]
for i in stuff[:1]:
    for j in i:
        print j
# Out:
# (COMMERCIAL BREAK)
#
# [21:00:35] ANDERSON COOPER, AC360 HOST:  Hey good evening.  Thanks for joining us 9:00 P.M., in New York, where we have breaking news.  New polling that will not be welcome news for Hillary Clinton, it is 6:00 P.M., the Reagan Library in Simi Valley, Southern California, site of next week's CNN Republican Presidential Debate.  Now just six days away, the breaking news on that, we can now say that these are the 11 candidates who qualify for the main debate.  Rand Paul, Huckabee, Marco Rubio, Ted Cruz, Dr. Ben Carson, Donald Trump, Jeb Bush, Scott Walker, Carly Fiorina, John Kasick, and Chris Christie.
#
# ...

# %%
'argh: fh'.split(': ')
# Out:
# ['argh', 'fh']
